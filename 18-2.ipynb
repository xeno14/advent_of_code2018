# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
a = np.loadtxt("18-2.txt").astype(np.int)

# %%
plt.plot(a)

# %%
a.shape
# Out:
# (1001,)

# %%
converged = a[-100:]

# %%
plt.plot(converged)

# %%
# find the frequency
peak_idx = np.arange(converged.shape[0])[converged == converged.min()]

# %%
peak_idx
# Out:
# array([ 3, 31, 59, 87])

# %%
peak_idx[1:] - peak_idx[:-1]
# Out:
# array([28, 28, 28])

# %%
# now I have the frequency
frequency = 28

# %%
mod = 1000000000 % 28

# %%
mod
# Out:
# 20

# %%
# unique values
istart = a.shape[0] - 100
values = a[istart:istart+frequency]

# %%
values
# Out:
# array([176390, 174114, 173850, 173545, 174114, 174420, 177010, 178825,
#        183330, 186713, 190674, 194400, 200734, 204680, 212046, 212176,
#        209682, 205870, 203742, 198830, 197232, 194805, 193224, 190491,
#        189175, 184506, 181007, 178097])

# %%
iend = 1000000000
mod = (iend - istart) % frequency

# %%
mod
# Out:
# 15

# %%
ans = values[mod]

# %%
ans
# Out:
# 212176
