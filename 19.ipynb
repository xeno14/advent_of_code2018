# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
reg = np.loadtxt("19.dat")

# %%
for i in range(6):
    plt.figure()
    plt.plot(reg[-10000:,i])
    plt.title(i)
